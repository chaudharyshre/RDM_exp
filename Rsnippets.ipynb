# %% [markdown]
# <a href="https://colab.research.google.com/github/chaudharyshre/RDM_exp/blob/main/Rsnippets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
library(readr)
library(ggplot2)
library(dplyr)

# %%
eyewitness_data <- data.frame(
  participant_ID = character(),
  participant_race = character(),
  perpetrator_race = character(),
  trial_classification = character(),
  identification_accuracy = numeric(),
  response_time = numeric(),
  age = numeric(),
  education_level = character(),
  stringsAsFactors = FALSE
)

write.csv (eyewitness_data, "raw eyewitness data", row.names = FALSE)

# %%
# example of a participant data
participant_data <- data.frame(
  participant_ID = "S0001",
  participant_race = "White/Caucasian",
  perpetrator_race = "Black/African American",
  trial_classification = "cross_race",
  identification_accuracy = 0,
  response_time = 6.72,
  age = 22,
  education_level = "some college",
  stringsAsFactors = FALSE
)

# %%
write.table (
  participant_data,
  file = "raw_eyewitness_data",
  sep = ",",
  row.names = FALSE,
  col.names = FALSE,
  append = TRUE
)

# %%
# Load all images
# Loading robbery sequences:
# Black_perpetrator_images
# White_perpetrator_images

# Load line up images for both races : image_name, is_perpetrator (TRUE/FALSE),race

# %%
# generate_unique_ID <- function() {}
# participant_ID = generate_unique_ID ()

# %%
random_number <- runif(1) # Define random_number

if (random_number < 0.5) {
  perpetrator_race = "White"
} else {
  perpetrator_race = "Black"
}
# Out:
# Error: object 'random_number' not found
# Traceback:

# %%
#Present lineup images
#load lineup images corresponding to perpetrator_race
#display all six images silmuntaneously
#start response timer
# detect participant click and stop timer

# %%
# compare selected image to perpetrator

if selected_image.is_perpetrator == TRUE:
 identification_accuracy = 1
 else
 identification_accuracy = 0
# Out:
# Error in parse(text = input): <text>:3:4: unexpected symbol
# 2:
# 3: if selected_image.is_perpetrator
#       ^
# Traceback:

# %%
if participant_race == perpetrator_race :
trial_classification = "same_race"
else:
trial_classification = "cross-race"

# %%
# loading data for analysis
eyewitness_data <- read.csv (
  "raw_eyewitness_data", # Corrected filename to match the written file
  stringsAsFactors = FALSE,
  header = FALSE # Added to correctly read data written without column names
)

# %%
filtered_data = filter (data, participant_race %in% c ("White/Caucasian", "Black/African American"))
grouped_data = group_by (filtered_data, trial_classification)

# %%
#computing mean
accuracy_summary <- filtered_data %>%
  group_by(trial_classification) %>%
  summarize(
    mean_accuracy = mean(identification_accuracy),
    n = n()
  )
# Out:
# Error: object 'filtered_data' not found
# Traceback:
#
# 1. summarize(., mean_accuracy = mean(identification_accuracy), n = n())
# 2. group_by(., trial_classification)
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'filtered_data' not found", base::quote(eval(expr,
#  .     envir)))

# %%
ggplot (
  accuracy_summary,
  aes (
  x= trial_classification,
  y= mean_accuracy
)
)
